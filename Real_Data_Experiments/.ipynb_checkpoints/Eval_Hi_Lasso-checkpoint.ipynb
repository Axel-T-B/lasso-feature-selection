# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, LassoLars
from sklearn.pipeline import make_pipeline
from sklearn.metrics import f1_score, mean_squared_error, average_precision_score
from sklearn.exceptions import ConvergenceWarning
from joblib import Parallel, delayed
from scipy.stats import binom

warnings.filterwarnings("ignore", category=ConvergenceWarning)

# ---------------------------------------------------------
# Phase 1: Hi-LASSO Procedure I (Importance Scores)
# ---------------------------------------------------------
def generate_importance_scores(b, X_train_scaled, y_train_scaled, q1, p, alpha_val):
    rs = np.random.default_rng(b + 100)
    n = X_train_scaled.shape[0]
    boot_rows = rs.choice(n, size=n, replace=True)
    boot_cols = rs.choice(p, size=q1, replace=False)
    
    # THE FIX: Use LassoLars to properly shrink noise, removing the forced quota!
    model = LassoLars(alpha=alpha_val, max_iter=2000)
    model.fit(X_train_scaled[boot_rows][:, boot_cols], y_train_scaled[boot_rows])
    return boot_cols, model.coef_

# ---------------------------------------------------------
# Phase 2: Hi-LASSO Procedure II (Adaptive LASSO)
# ---------------------------------------------------------
def adaptive_feature_refinement(b, X_train_scaled, y_train_scaled, q2, p, importances, alpha_val):
    rs = np.random.default_rng(b + 200)
    n = X_train_scaled.shape[0]
    boot_rows = rs.choice(n, size=n, replace=True)
    
    # THE FIX: Exact probability normalization to prevent the NumPy crash
    prob_weights = importances / np.sum(importances)
    prob_weights = prob_weights / np.sum(prob_weights) 
    
    boot_cols = rs.choice(p, size=q2, replace=False, p=prob_weights)
    
    # Strictly Basic LASSO as requested (not adaptive lasso)
    model = LassoLars(alpha=alpha_val, max_iter=2000)
    model.fit(X_train_scaled[boot_rows][:, boot_cols], y_train_scaled[boot_rows])
    return boot_cols, model.coef_

# ---------------------------------------------------------
# Math Helpers
# ---------------------------------------------------------
def calc_rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def calc_rme(beta_true, beta_hat):
    return np.linalg.norm(beta_hat - beta_true) / (np.linalg.norm(beta_true) + 1e-10)

def calc_rme_nonzeros(beta_true, beta_hat):
    mask = beta_true != 0
    return np.linalg.norm(beta_hat[mask] - beta_true[mask]) / (np.linalg.norm(beta_true[mask]) + 1e-10)

# %%
# =========================================================
# Main Hi-LASSO Execution Pipeline
# =========================================================
datasets = ["Dataset_I", "Dataset_II", "Dataset_III", "Dataset_IV"]
versions = ["v0", "v1", "v2", "v3", "v4", "v5", "v6", "v7", "v8", "v9"] 
#versions = ["v0"]
alphas = [10.0, 1.0, 1e-1, 1e-2, 1e-3]

hilasso_scores = []

for name in datasets:
    print(f"\nProcessing Hi-LASSO for {name}...")
    for v in versions:
        
        # 1. Load & Scale Data
        X = pd.read_csv(f'Simulation_Data/X_{name}_{v}.csv').values
        y = pd.read_csv(f'Simulation_Data/y_{name}_{v}.csv').values.ravel()
        true_betas = pd.read_csv(f'Simulation_Data/beta_{name}_{v}.csv').values.ravel()

        X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=(1/6), random_state=42)
        X_scaler = StandardScaler()
        X_train_scaled = X_scaler.fit_transform(X_train)
        X_val_scaled = X_scaler.transform(X_val)
        
        y_scaler = StandardScaler()
        y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1)).ravel()
        y_val_scaled = y_scaler.transform(y_val.reshape(-1, 1)).ravel()

        p = X.shape[1]
        true_selected = (true_betas != 0).astype(int)

        q1, q2 = X_train_scaled.shape[0], X_train_scaled.shape[0]
        B_rand = int((p / q1) * 30)

        best_h_f1, best_h_auprc, best_h_rme_all, best_h_rme_nz = 0, 0, 0, 0
        best_h_rmse = np.inf 
        best_raw_coefs = None
        best_importances = None
        
        # 2. FULL SWEEP (Phase 1 and Phase 2 tune together!)
        for a in alphas:
            # --- PHASE 1 ---
            p1_results = Parallel(n_jobs=-1, batch_size=100)(
                delayed(generate_importance_scores)(b, X_train_scaled, y_train_scaled, q1, p, a) for b in range(B_rand)
            )
            
            importances = np.zeros(p)
            times_selected_p1 = np.zeros(p)
            for boot_cols, boot_coefs in p1_results:
                importances[boot_cols] += np.abs(boot_coefs)
                times_selected_p1[boot_cols] += 1
                
            # True coefficient scaling & Crash Prevention
            importances = np.divide(importances, times_selected_p1, out=np.zeros_like(importances), where=times_selected_p1!=0)
            importances[importances == 0] = 1e-10 
            
            # --- PHASE 2 ---
            p2_results = Parallel(n_jobs=-1, batch_size=100)(
                delayed(adaptive_feature_refinement)(b, X_train_scaled, y_train_scaled, q2, p, importances, a) for b in range(B_rand)
            )
            
            hilasso_coef_sums = np.zeros(p)
            times_selected_p2 = np.zeros(p)
            
            for boot_cols, boot_coefs in p2_results:
                hilasso_coef_sums[boot_cols] += boot_coefs
                times_selected_p2[boot_cols] += 1
                non_zero_idx = boot_cols[np.abs(boot_coefs) > 1e-6]
                
            raw_final_coef = np.divide(hilasso_coef_sums, times_selected_p2, out=np.zeros_like(hilasso_coef_sums), where=times_selected_p2!=0)
            
            # --- HONEST ALPHA TUNING ---
            temp_coef_rmse = raw_final_coef.copy()
            temp_coef_rmse[np.abs(temp_coef_rmse) < 1e-6] = 0.0
            
            h_pred = X_val_scaled @ temp_coef_rmse
            current_rmse = calc_rmse(y_val_scaled, h_pred)
            
            if current_rmse < best_h_rmse:
                best_h_rmse = current_rmse
                best_alpha = a
                best_raw_coefs = raw_final_coef.copy()
                best_importances = importances.copy()

        # --- EVALUATION ---
        # The AUPRC strictly evaluates the Phase 1 Importance Scores
        best_h_auprc = average_precision_score(true_selected, best_importances)

        # Jul 10 change at 2:15pm - Expanded Relative Grid: 
        # Hi-LASSO's superior coefficients can safely handle lower bounds 
        # to boost Recall without hoarding noise.
        relative_fractions = [0.01, 0.025, 0.05, 0.10, 0.15, 0.20, 0.30]
        max_coef = np.max(np.abs(best_raw_coefs))
        
        best_h_rmse_eval = np.inf
        best_h_f1 = 0
        best_thresh = 0
        
        for frac in relative_fractions:
            thresh = frac * max_coef
            
            temp_eval = best_raw_coefs.copy()
            temp_eval[np.abs(temp_eval) < thresh] = 0.0
            
            h_pred = X_val_scaled @ temp_eval
            current_rmse = calc_rmse(y_val_scaled, h_pred)
            
            if current_rmse < best_h_rmse_eval:
                best_h_rmse_eval = current_rmse
                best_thresh = thresh
                
                best_h_f1 = f1_score(true_selected, (np.abs(temp_eval) > 0).astype(int))
                best_h_rme_all = calc_rme(true_betas, temp_eval)
                best_h_rme_nz = calc_rme_nonzeros(true_betas, temp_eval)

        # Update the main tracking variables for the final output
        best_h_rmse = best_h_rmse_eval

        hilasso_scores.append({
            "Dataset": name, "Seed": v, 
            "H_RMSE": best_h_rmse, "H_F1": best_h_f1, "H_AUPRC": best_h_auprc,
            "H_RME_All": best_h_rme_all, "H_RME_Nz": best_h_rme_nz
        })
        
        # THE FIX: Update the print statement to use the 'best' variables so it reports the true winner!
        print(f"  > Completed {v} | Alpha: {best_alpha} | F1: {best_h_f1:.4f} | RMSE: {best_h_rmse:.4f}")
    print("\n")

# Calculate final aggregated statistics
df_results = pd.DataFrame(hilasso_scores)
df_results.to_csv("hilasso_scores.csv", index=False)

print("==========================================")
print("Final Hi-LASSO Results (Averaged by Dataset)")
print("==========================================")

# Group by Dataset and calculate averages
grouped_results = df_results.groupby('Dataset')

for dataset_name, group in grouped_results:
    print(f"--- {dataset_name} ---")
    for metric in ['H_F1', 'H_RMSE', 'H_AUPRC', 'H_RME_All', 'H_RME_Nz']:
        avg = group[metric].mean()
        std = group[metric].std()
        print(f"  {metric:<10}: {avg:.4f} ± {std:.4f}")
    print()
    
print("==========================================")
print("\nDone! Saved all granular results to hilasso_scores.csv.")
# Out:
# Processing Hi-LASSO for Dataset_I...
#   > Completed v0 | Alpha: 0.001 | F1: 0.6400 | RMSE: 0.2225
#   > Completed v1 | Alpha: 0.1 | F1: 0.7368 | RMSE: 0.3229
#   > Completed v2 | Alpha: 0.1 | F1: 0.5714 | RMSE: 0.3202
#   > Completed v3 | Alpha: 0.1 | F1: 0.6667 | RMSE: 0.3654
#   > Completed v4 | Alpha: 0.001 | F1: 0.8235 | RMSE: 0.2607
#   > Completed v5 | Alpha: 0.1 | F1: 0.7778 | RMSE: 0.2454
#   > Completed v6 | Alpha: 0.1 | F1: 0.7059 | RMSE: 0.2679
#   > Completed v7 | Alpha: 0.1 | F1: 0.7059 | RMSE: 0.2703
#   > Completed v8 | Alpha: 0.1 | F1: 0.5000 | RMSE: 0.1761
#   > Completed v9 | Alpha: 0.01 | F1: 0.5161 | RMSE: 0.2063
#
#
#
# Processing Hi-LASSO for Dataset_II...
#   > Completed v0 | Alpha: 0.1 | F1: 0.6207 | RMSE: 0.3887
#   > Completed v1 | Alpha: 0.1 | F1: 0.6780 | RMSE: 0.3001
#   > Completed v2 | Alpha: 0.1 | F1: 0.4444 | RMSE: 0.4043
#   > Completed v3 | Alpha: 0.1 | F1: 0.5049 | RMSE: 0.4377
#   > Completed v4 | Alpha: 0.1 | F1: 0.5495 | RMSE: 0.3961
#   > Completed v5 | Alpha: 0.1 | F1: 0.6512 | RMSE: 0.2931
#   > Completed v6 | Alpha: 0.1 | F1: 0.6977 | RMSE: 0.2930
#   > Completed v7 | Alpha: 0.1 | F1: 0.4545 | RMSE: 0.3877
#   > Completed v8 | Alpha: 0.1 | F1: 0.5075 | RMSE: 0.4558
#   > Completed v9 | Alpha: 0.1 | F1: 0.6742 | RMSE: 0.2757
#
#
#
# Processing Hi-LASSO for Dataset_III...
#   > Completed v0 | Alpha: 0.1 | F1: 0.5915 | RMSE: 0.2761
#   > Completed v1 | Alpha: 0.1 | F1: 0.7013 | RMSE: 0.3490
#   > Completed v2 | Alpha: 0.1 | F1: 0.6579 | RMSE: 0.4423
#   > Completed v3 | Alpha: 0.1 | F1: 0.6750 | RMSE: 0.3666
#   > Completed v4 | Alpha: 0.1 | F1: 0.4062 | RMSE: 0.5013
#   > Completed v5 | Alpha: 0.1 | F1: 0.5075 | RMSE: 0.4282
#   > Completed v6 | Alpha: 0.1 | F1: 0.7327 | RMSE: 0.3167
#   > Completed v7 | Alpha: 0.1 | F1: 0.4068 | RMSE: 0.3165
#   > Completed v8 | Alpha: 0.1 | F1: 0.7955 | RMSE: 0.3102
#   > Completed v9 | Alpha: 0.1 | F1: 0.7308 | RMSE: 0.3235
#
#
#
# Processing Hi-LASSO for Dataset_IV...
#   > Completed v0 | Alpha: 0.1 | F1: 0.6111 | RMSE: 0.2848
#   > Completed v1 | Alpha: 0.1 | F1: 0.7805 | RMSE: 0.3548
#   > Completed v2 | Alpha: 0.1 | F1: 0.5505 | RMSE: 0.5935
#   > Completed v3 | Alpha: 0.1 | F1: 0.6486 | RMSE: 0.4840
#   > Completed v4 | Alpha: 0.1 | F1: 0.5507 | RMSE: 0.4294
#   > Completed v5 | Alpha: 0.1 | F1: 0.7805 | RMSE: 0.4148
#   > Completed v6 | Alpha: 0.1 | F1: 0.8235 | RMSE: 0.3597
#   > Completed v7 | Alpha: 0.1 | F1: 0.6111 | RMSE: 0.3896
#   > Completed v8 | Alpha: 0.1 | F1: 0.7179 | RMSE: 0.3842
#   > Completed v9 | Alpha: 0.1 | F1: 0.7179 | RMSE: 0.4292
#
#
# ==========================================
# Final Hi-LASSO Results (Averaged by Dataset)
# ==========================================
# --- Dataset_I ---
#   H_F1      : 0.6644 ± 0.1081
#   H_RMSE    : 0.2658 ± 0.0578
#   H_AUPRC   : 0.8211 ± 0.0958
#   H_RME_All : 0.9408 ± 0.0237
#   H_RME_Nz  : 0.9407 ± 0.0240
#
# --- Dataset_II ---
#   H_F1      : 0.5782 ± 0.0972
#   H_RMSE    : 0.3632 ± 0.0663
#   H_AUPRC   : 0.5214 ± 0.0742
#   H_RME_All : 0.9808 ± 0.0043
#   H_RME_Nz  : 0.9808 ± 0.0043
#
# --- Dataset_III ---
#   H_F1      : 0.6205 ± 0.1380
#   H_RMSE    : 0.3630 ± 0.0716
#   H_AUPRC   : 0.4773 ± 0.1135
#   H_RME_All : 0.9755 ± 0.0049
#   H_RME_Nz  : 0.9755 ± 0.0049
#
# --- Dataset_IV ---
#   H_F1      : 0.6792 ± 0.0987
#   H_RMSE    : 0.4124 ± 0.0831
#   H_AUPRC   : 0.6098 ± 0.1115
#   H_RME_All : 0.9779 ± 0.0040
#   H_RME_Nz  : 0.9779 ± 0.0040
#
# ==========================================
#
# Done! Saved all granular results to hilasso_scores.csv.
